# %%
import torchvision
import torch
import torchvision.transforms as transforms
import random
import numpy as np
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch.utils.data import Subset
from collections import Counter
from collections import defaultdict
from torchvision import transforms
import matplotlib.pyplot as plt
from collections import Counter
from collections import OrderedDict
import torch.nn as nn
import time
import os
import torch
import copy
import torch.nn.functional as F
import wandb
import json
import heapq
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker


# Seeds for reproducibility
def set_seeds(seed: int = 123):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seeds(123)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
""" PLOT SETTINGS """

plt.style.use("seaborn-v0_8")
plt.rcParams.update({
    "font.size": 18,            # base font size
    "axes.titlesize": 24,       # axis titles
    "axes.labelsize": 22,       # axis labels
    "xtick.labelsize": 18,      # X axis numbers
    "ytick.labelsize": 18,      # Y axis numbers
    "legend.fontsize": 18,      # legend text
    "lines.linewidth": 3.0      # line thickness
})

# %%
# --- Define DINOWithHead ---
class DINOWithHead(nn.Module):
    def __init__(self, backbone, num_classes=100, p=None):
        super().__init__()
        self.backbone = backbone
        layers = []
        if p is not None:
            layers.append(nn.Dropout(p=p))
        layers.append(nn.Linear(384, num_classes))
        self.head = nn.Sequential(*layers)

    def forward(self, x):
        features = self.backbone(x)
        out = self.head(features)
        return out

# %% [markdown]
# ## Data import and loader creation

# %%
""" DATASET DOWNLOAD """
ROOT = './data'
BATCH_SIZE=64
#BATCH_SIZE = 128
NUM_WORKERS = os.cpu_count()

tot_train_data = torchvision.datasets.CIFAR100(root=ROOT, train=True, download=True, transform=torchvision.transforms.ToTensor())
test_data = torchvision.datasets.CIFAR100(root=ROOT, train=False, download=True, transform=torchvision.transforms.ToTensor())





""" SPLIT TOT_TRAININ in VALIDATION and TRAIN """

def split_dataset(tot_train_data, valid_ratio=0.8):
    """
    Splits the given dataset randomly into training and validation subsets
    """
    train_size = int(valid_ratio * len(tot_train_data))
    val_size = len(tot_train_data) - train_size
    train_data, val_data = random_split(tot_train_data, [train_size, val_size])
    return train_data, val_data

train_data, val_data = split_dataset(tot_train_data, valid_ratio=0.8)



""" DATA TRANSFORMATION """

def data_trasform(dataset, data_augmentation=False):   ### train_data or tot_train_data
    """
    Returns train and val/test transforms based on dataset stats.
    Dataset (for computing mean and std) can be either training only or combined train+validation.

    If data_augmentation=True, applies augmentation on training transforms, otherwise only resize and normalize.
    """

    # MEAN and VARIANCE (considering 3 channels)
    mean = torch.zeros(3)
    std = torch.zeros(3)
    nb_samples = 0

    for img, _ in dataset:
        img = img.view(3, -1)  # Flatten H*W in seconda dimensione
        mean += img.mean(1)
        std += img.std(1)
        nb_samples += 1

    mean /= nb_samples
    std /= nb_samples


    if data_augmentation:
        train_transforms = transforms.Compose([
            transforms.Resize(64, interpolation=transforms.InterpolationMode.BILINEAR),
            transforms.RandomCrop(64, padding=4),
            transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(degrees=15),
            transforms.RandAugment(num_ops=2, magnitude=9),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])
    else:
        train_transforms = transforms.Compose([
            transforms.Resize(64, interpolation=transforms.InterpolationMode.BILINEAR),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])

    ### NO DATA AUGMENTATION!
    val_test_transforms = transforms.Compose([
        transforms.Resize(64),                    # Resize
        transforms.ToTensor(),                     # Convert to tensor
        transforms.Normalize(mean=mean, std=std)   # Normalization using the training statistics
    ])


    return train_transforms, val_test_transforms






""" DATA TRANSFORMATION and LOADERS """

### ===== For hyperparameter tuning considering train_data and val_data =====
train_transforms, val_test_transforms = data_trasform(train_data)

train_data.dataset.transform = train_transforms
val_data.dataset.transform = val_test_transforms

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader   = DataLoader(val_data,   batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)



### ===== For model testing considering tot_train_data and test_data =====
train_transforms, val_test_transforms = data_trasform(tot_train_data)

tot_train_data = torchvision.datasets.CIFAR100(root=ROOT, train=True, download=False, transform=train_transforms)
test_data = torchvision.datasets.CIFAR100(root=ROOT, train=False, download=False, transform=val_test_transforms)

tot_train_loader = DataLoader(tot_train_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)

# %% [markdown]
# ## Functions Client

# %%
""" SPLIT INTO K CLIENTS: iid and non-iid distributions  """

def iid_shard(dataset, K):
    """
    Splits the dataset into K disjoint subsets (one per client) in an IID fashion. Each client receives ~len(dataset)/K samples,
    drawn uniformly at random across all classes.
    """
    num_items_per_client = len(dataset) // K
    remainder = len(dataset) % K
    all_indices = list(range(len(dataset)))
    random.shuffle(all_indices)

    client_data = {}  # Creation of a dictionary for clients
    start = 0
    for i in range(K):
        # give +1 to the first `remainder` clients
        add = num_items_per_client + (1 if i < remainder else 0)
        end = start + add
        client_data[i+1] = Subset(dataset, all_indices[start:end])
        start = end

    return client_data


def noniid_shard(dataset, K, Nc):
    """
    Splits the dataset into K disjoint subsets (one per client) in a non-IID fashion.
    Disjoint dataset: each sample must belong to exactly one client and cannot be duplicated.
    Nc: each client receives samples from Nc distinct classes, to simulate variability of data across clients.
    """
    # === Feasibility check ===
    all_classes = set(label for _, label in dataset)
    num_classes = len(all_classes)
    if Nc > num_classes:
        raise ValueError(f"Cannot assign {Nc} classes per client: only {num_classes} classes available.")


    # === Step 1: Organize data by class ===
    # This ensures we can select samples from specific classes without duplication.
    label_to_indices = defaultdict(list)
    for idx, (_, label) in enumerate(dataset):
        label_to_indices[label].append(idx)    # key: class, value: list of idxs of the corresponding class

    # === Step 2: Shuffle samples within each class ===
    # Prevents consecutive samples from going to the same clients repeatedly.
    for cls in label_to_indices:
        random.shuffle(label_to_indices[cls])

    # === Step 3: Prepare the list of clients and shuffle it ===
    # Guarantees random assignment of classes to clients.
    all_classes = list(label_to_indices.keys())

    client_class_map = {}
    for client_id in range(1, K+1):        # Pre-select Nc classes per client at the beginning.
        client_class_map[client_id] = random.sample(all_classes, Nc)

    client_data = {cid: [] for cid in range(1, K+1)}    # Initialize empty client datasets
    class_to_clients = defaultdict(list)     # For each class, keep track of clients that have it (reverse map from class → clients that have that class)
    for cid, classes in client_class_map.items():
        for cls in classes:
            class_to_clients[cls].append(cid)


    # === Step 4: Distribute samples in rounds ===
    # Distributing samples to clients in rounds
    for cls, indices in label_to_indices.items():    # Iterate over all classes, where indices is the list of the samples for the considered class
        clients = class_to_clients[cls]  # clients that want this class
        if not clients:
            continue
        i = 0
        while indices:
            client_id = clients[i % len(clients)]  # cycling continuously through the list of clients
            sample = indices.pop()                 # take one sample and it removes it so it will not be repeated
            client_data[client_id].append(sample)  # assign to this client
            i += 1

     # === Step 5: Convert sample index lists into Subsets ===
    for cid in client_data:
        client_data[cid] = Subset(dataset, client_data[cid])

    return client_data

# %% [markdown]
# ## Class Client

# %%
def compress_mask(mask_dict):
    """
    Convert each 0/1 tensor in the mask into a compressed bit array.
    Returns a dictionary: {param_name: (packed_uint8_array, original_shape)}
    """
    compressed = {}
    for name, tensor in mask_dict.items():
        # Move tensor to CPU, cast to uint8, flatten, and convert to numpy
        arr = tensor.detach().to('cpu').to(torch.uint8).contiguous().view(-1).numpy()
        # Pack bits into a compact representation (8x smaller than uint8)
        packed = np.packbits(arr)
        compressed[name] = (packed, tuple(tensor.shape))  # store packed data + original shape
    return compressed


def decompress_mask(compressed_dict):
    """
    Reconstruct torch.uint8 tensors with the original shape (0/1 values).
    """
    mask = {}
    for name, (packed, shape) in compressed_dict.items():
        total = int(np.prod(shape))  # number of elements in original tensor
        # Unpack bits back to 0/1 and trim extra padding
        unpacked = np.unpackbits(packed)[:total]
        # Reshape to original tensor shape and convert to torch.uint8
        mask[name] = torch.from_numpy(unpacked.reshape(shape)).to(torch.uint8)
    return mask



""" CLASS CLIENT"""
class Client:
    def __init__(self, client_id, dataset, loader,
                 mask=None, extra_mask=None, fisher_scores=None,
                 local_weights=None, compressed_mask=None):
        self.client_id = client_id
        self.dataset = dataset
        self.loader = loader

        # Full mask in RAM (0/1 tensors) – only needed during training
        self.mask = mask

        # Lightweight storage version (bit-packed mask)
        self.compressed_mask = compressed_mask

        # Optional: additional mask (depends on your logic)
        self.extra_mask = extra_mask

        # Fisher scores are only needed during calibration;
        # after that, you can set them to None to save memory
        self.fisher_scores = fisher_scores

        # Local weights are not really used in your training loop;
        # kept here only for compatibility
        self.local_weights = local_weights

    def compress_mask(self):
        """
        Compress self.mask into self.compressed_mask and free RAM
        """
        if self.mask is not None:
            # Make sure mask tensors are uint8 (0/1 values)
            self.mask = {k: v.to(torch.uint8) for k, v in self.mask.items()}
            self.compressed_mask = compress_mask(self.mask)
            self.mask = None  # release memory

    def decompress_mask(self):
        """
        Rebuild self.mask (0/1 tensors) from self.compressed_mask
        """
        if self.compressed_mask is not None and self.mask is None:
            self.mask = decompress_mask(self.compressed_mask)



    def num_samples(self):
        """
        Returns the number of samples in the client’s local dataset.
        """
        return len(self.dataset)

    @staticmethod
    def print_samples(clients):
        """
        Prints the number of samples each client holds.
        """
        print("Number of samples per client:")
        for client in clients:
            print(f"Client {client.client_id}: {client.num_samples()} samples")

    @staticmethod
    def plot_class_distribution(clients, dataset):
        """
        Plots the distribution of classes for a list of clients.
        """
        class_distributions = []

        if hasattr(dataset, 'targets'):
            get_label = lambda idx: dataset.targets[idx]
        elif hasattr(dataset, 'labels'):
            get_label = lambda idx: dataset.labels[idx]
        else:
            get_label = lambda idx: dataset[idx][1]

        for client in clients:
            indices = client.loader.dataset.indices if isinstance(client.loader.dataset, Subset) else list(range(len(client.loader.dataset)))
            labels = [get_label(i) for i in indices]
            class_counts = Counter(labels)
            class_distributions.append(class_counts)

        fig, axes = plt.subplots(nrows=1, ncols=len(clients), figsize=(5 * len(clients), 4))
        if len(clients) == 1:
            axes = [axes]

        for i, (client, class_counts) in enumerate(zip(clients, class_distributions)):
            axes[i].bar(class_counts.keys(), class_counts.values(), color='orange')
            axes[i].set_title(f'Client {client.client_id}')
            axes[i].set_xlabel('Classes')
            axes[i].set_ylabel('Frequency')
            axes[i].set_xticks(list(class_counts.keys()))

        plt.tight_layout()
        plt.show()



""" CLIENT CREATION """
def create_clients(data, K, Nc=None, flag = "iid"):   ### data is either train_data or tot_data
    """
    Splits the dataset into K subsets, either IID or non-IID, and returns both the client datasets and their corresponding DataLoaders
    """
    if flag == "iid":     # We want iid
      client_datasets = iid_shard(data, K)     # Split the training data into K clients

    else:    # We want non iid
      client_datasets = noniid_shard(data, K, Nc)

    client_loaders = {}    ### Creation of a DataLoader for each client

    for client_id, subset in client_datasets.items():
        loader = DataLoader(subset, batch_size=BATCH_SIZE, shuffle=True)
        client_loaders[client_id] = loader       # The clients id are the indices+1
    return client_datasets, client_loaders


def create_client_objects(data, K, Nc=None, flag="iid", batch_size=64, verbose=True):
    """
    Creates and returns a list of Client objects, each containing its own dataset and DataLoader, ready for use in federated learning
    """

    # === CHECK ===
    if flag == "non-iid" and Nc is None:
        raise ValueError("Nc must be set when flag='non-iid'")

    client_datasets, client_loaders = create_clients(data, K, Nc, flag=flag)
    clients = []
    for client_id in client_datasets.keys():
        clients.append(Client(client_id, client_datasets[client_id], client_loaders[client_id]))


    if verbose:
        print("Clients and their sample sizes:")
        for client in clients:
            print(f"Client {client.client_id}: {client.num_samples()} samples")

    return clients

# %% [markdown]
# ## Server model evaluation

# %%
""" MODEL EVALUATION """
def evaluate_model(model, data_loader, criterion):
    """
    The evaluate_model function computes the average loss and accuracy of a model on a dataset without updating its weights.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    total_loss = 0.0
    total_corrects = 0

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            total_corrects += torch.sum(preds == labels.data)

    avg_loss = total_loss / len(data_loader.dataset)
    avg_acc = total_corrects.double() / len(data_loader.dataset)

    return avg_loss, avg_acc.item()

# %%
""" CHECKPOINT FUNCTION """
def save_checkpoint(model, epoch, train_losses, train_accuracies,
                    val_test_losses, val_test_accuracies, best_acc, best_loss, best_model_wts, path):
    """
    The save_checkpoint function saves the model’s state, training/validation metrics,
    and best performance to a specified file path.
    """
    dir_name = os.path.dirname(path)
    if dir_name:
        os.makedirs(dir_name, exist_ok=True)
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'train_losses': train_losses,
        'train_accuracies': train_accuracies,
        'val_test_losses': val_test_losses,
        'val_test_accuracies': val_test_accuracies,
        'best_acc': best_acc,
        'best_loss': best_loss,
        'best_model_state_dict': best_model_wts
    }
    torch.save(checkpoint, path)



def init_checkpoint(model, path=None, device='cpu', verbose = True):
    """
    Initialize a checkpoint. If path is None, create default checkpoint with empty/default values.
    If path is given and file exists, load it.
    Returns: start_epoch, best_acc, best_loss, train_losses, train_accuracies, val_test_losses, val_test_accuracies, checkpoint_path, best_model_wts
    """
    if path is None:
        # default path
        os.makedirs("checkpoints", exist_ok=True)
        path = "checkpoints/latest.pth"
        if verbose:
            print(f"Initializing new checkpoint at {path}")
        # save default empty checkpoint
        checkpoint = {
            'epoch': 1,
            'best_acc': 0.0,
            'best_loss': 1e10,
            'train_losses': [],
            'train_accuracies': [],
            'val_test_losses': [],
            'val_test_accuracies': [],
            'model_state_dict': model.state_dict(),
            'best_model_state_dict': copy.deepcopy(model.state_dict())
        }
        torch.save(checkpoint, path)
        return 1, 0.0, 1e10, [], [], [], [], path, copy.deepcopy(model.state_dict())

    else:
        # load existing checkpoint
        if not os.path.isfile(path):
            raise FileNotFoundError(f"Checkpoint file {path} does not exist.")

        print(f"Loading checkpoint from {path}")
        checkpoint = torch.load(path, map_location=device, weights_only=False)
        model.load_state_dict(checkpoint['model_state_dict'])
        best_model_wts = checkpoint.get('best_model_state_dict', copy.deepcopy(model.state_dict()))
        return (checkpoint['epoch'],
                checkpoint.get('best_acc', 0.0),
                checkpoint.get('best_loss', 1e10),
                checkpoint.get('train_losses', []),
                checkpoint.get('train_accuracies', []),
                checkpoint.get('val_test_losses', []),
                checkpoint.get('val_test_accuracies', []),
                path,
                best_model_wts )

# %% [markdown]
# ## Train client

# %%
""" TRAINING FUNCTION """
def train_model_client(model, criterion, optimizer, scheduler, client: Client, J=5, device=None):    ### Single client
    """
    Trains a model locally on a single client for J epochs.
    Performs forward pass, computes loss, backpropagation, and updates weights using the given optimizer.
    """
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    train_loader = client.loader

    # ========== TRAINING ==========
    for j in range(J):   # "inner" loop
        model.train()
        train_loss = 0.0
        train_corrects = 0

        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            train_corrects += torch.sum(preds == labels).item()

        if scheduler is not None:
            scheduler.step()

        epoch_train_loss = train_loss / len(train_loader.dataset)
        epoch_train_acc = train_corrects / len(train_loader.dataset)

    return epoch_train_loss, epoch_train_acc    # Return the last performances

# %% [markdown]
# ## Mask & Fine tuning

# %%
""" MASK COMPUTATION & CALIBRATION """

def compute_fisher_scores(client, model, device):
    """
    Compute diagonal Fisher Information scores for a client using client.loader.
    Stores results in client.fisher_scores.
    """
    model.eval()  # set model to evaluation mode

    # Initialize Fisher scores if not already present
    if not hasattr(client, 'fisher_scores') or client.fisher_scores is None:
        client.fisher_scores = {
            name: torch.zeros_like(param, device="cpu")
            for name, param in model.named_parameters() if param.requires_grad
        }

    num_batches = 0  # counter for normalization

    # Iterate over client data
    for inputs, labels in client.loader:
        num_batches += 1
        inputs, labels = inputs.to(device), labels.to(device)

        model.zero_grad()  # reset gradients
        outputs = model(inputs)

        # Compute log-probabilities
        log_probs = F.log_softmax(outputs, dim=1)

        # Sample labels from the predicted distribution: y ~ p(y|x)
        sampled_y = torch.multinomial(log_probs.exp(), num_samples=1).squeeze(-1)

        # Compute NLL loss on sampled labels and backpropagate
        loss = F.nll_loss(log_probs, sampled_y, reduction="mean")
        loss.backward()

        # Accumulate squared gradients for each parameter
        for name, param in model.named_parameters():
            if param.grad is not None:
                client.fisher_scores[name] += param.grad.detach().cpu() ** 2

    # Normalize Fisher scores by number of batches
    for name in client.fisher_scores.keys():
        client.fisher_scores[name] /= num_batches





def calibrate_mask_for_client(client, model, device, R=5, final_sparsity=0.9, lr=0.005, weight_decay=0.00005 , keep="least"):
    # Initial mask: all ones (uint8) only for trainable parameters
    mask = {name: torch.ones_like(param, device="cpu", dtype=torch.uint8)
            for name, param in model.named_parameters() if param.requires_grad}
    client.mask = mask  # store in RAM

    # Recompute Fisher scores and update mask R times
    for r in range(1, R + 1):
        current_density = (1 - final_sparsity) ** (r / R)
        current_sparsity = 1 - current_density
        print(f"[Round = {r}] Sparsity = {current_sparsity:.4f}")

        compute_fisher_scores(client, model, device)
        fisher_scores = client.fisher_scores  # dict {name: tensor float}

        # --- Flatten all scores ---
        all_scores = torch.cat([score.view(-1) for score in fisher_scores.values()])

        # --- Compute global threshold using topk ---
        num_keep_global = int(len(all_scores) * current_density)
        num_keep_global = max(1, min(num_keep_global, len(all_scores)))

        if keep == "least":
            # keep the least important weights
            _, idx = torch.topk(all_scores, k=num_keep_global, largest=False)
        elif keep == "most":
            # keep the most important weights
            _, idx = torch.topk(all_scores, k=num_keep_global, largest=True)
        elif keep == "random":
            idx = torch.randperm(len(all_scores))[:num_keep_global]
        else:
            raise ValueError("keep must be 'least', 'most', or 'random'")

        # build global_keep mask
        global_keep = torch.zeros_like(all_scores, dtype=torch.bool)
        global_keep[idx] = True

        # --- Redistribute threshold layer by layer ---
        new_mask = {}
        start = 0
        for name, score in fisher_scores.items():
            numel = score.numel()
            keep_tensor = global_keep[start:start+numel].view_as(score)
            new_mask[name] = (keep_tensor.to(torch.uint8) * client.mask[name])
            start += numel

        # update current mask
        client.mask = new_mask
        total_ones = sum(mask.sum().item() for mask in client.mask.values())
        #print(f"Total active parameters in mask: {total_ones}")
        total_params = sum(mask.numel() for mask in client.mask.values())
        perc_active = 100 * total_ones / total_params
        print(f"Active parameters: {total_ones}/{total_params} ({perc_active:.2f}%)")

        # mini-training with SparseSGD + current mask
        param_to_name = {id(param): n for n, param in model.named_parameters()}
        optimizer = SparseSGD(model.parameters(), lr=lr, weight_decay=weight_decay, mask_dict=client.mask, param_to_name=param_to_name)
        local_model = copy.deepcopy(model).to(device)
        train_model_client(local_model, criterion=nn.CrossEntropyLoss(), optimizer=optimizer,
                           scheduler=None, client=client, J=1, device=device)

    # End of calibration: discard Fisher scores from memory
    client.fisher_scores = None

    # Compress the mask for lightweight storage
    client.compress_mask()




def calibrate_all_clients(clients, global_model, device, R=5, final_sparsity=0.9, lr=0.005, weight_decay=0.00005, keep ="least"):
    """
    Apply mask calibration for all clients.
    """
    for client in clients:
        calibrate_mask_for_client(client, global_model, device, R=R, final_sparsity=final_sparsity, lr=lr, weight_decay=weight_decay, keep=keep)
        print(f"Client {client.client_id} -> mask calibrated (sparsity={final_sparsity})")

# %% [markdown]
# ## SparseSGD

# %%
import torch
from torch.optim import SGD

class SparseSGD(torch.optim.SGD):
    def __init__(self, params, lr=0.01, momentum=0, weight_decay=0, mask_dict=None, param_to_name=None):
        super().__init__(params, lr=lr, momentum=momentum, weight_decay=weight_decay)
        self.mask_dict = mask_dict  # {name: mask_tensor on CPU}
        self.param_to_name = param_to_name or {}

    @torch.no_grad()
    def step(self, closure=None):
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()

        # Before calling super().step: modify gradients according to the mask
        if self.mask_dict is not None:
            for group in self.param_groups:
                for p in group['params']:
                    if p.grad is None:
                        continue
                    name = self.param_to_name.get(id(p), None)
                    if name is not None and name in self.mask_dict:
                        mask = self.mask_dict[name].to(p.device)
                        # Apply the mask to the gradient (blocks updates for masked-out weights)
                        p.grad.mul_(mask.to(dtype=p.grad.dtype))  # CORRESPONDS TO: d_p = d_p * mask

        # Now let SGD perform its usual step (momentum, weight_decay, etc.)
        super().step(closure)

        return loss

# %% [markdown]
# ## Main Training FL

# %%
def train_test_model_FL(global_model, criterion, LR, MOMENTUM, WEIGHT_DECAY, T_MAX, clients, val_test_loader,
                        num_epochs, C, J, checkpoint_path=None, checkpoints=True, verbose=True,
                        use_sparse=False, send_only_mask_updates=False, count=False):
    """
    Federated Learning training loop with FedAvg aggregation and optional SparseSGD.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    val_test_loss_s, val_test_acc_s, avg_train_loss_s, avg_train_acc_s = [], [], [], []

    # Initial copy of global weights
    fed_model_weights = {k: v.clone().detach() for k, v in global_model.state_dict().items()}
    tot_comm = 0

    for epoch in range(num_epochs):
        comm_this_round = 0    # To count the number of communicated parameters
        round_train_losses = []
        round_train_accs = []

        if verbose or epoch == 0 or (epoch + 1) % 5 == 0:
            print(f"\n--- Federated Round {epoch+1}/{num_epochs} ---")

        # Sample a fraction of clients
        num_clients = max(1, int(C * len(clients)))
        selected_clients = np.random.choice(clients, num_clients, replace=False)

        local_weights = []
        local_sizes = []

        for client in selected_clients:
            # Copy of the global model for local training
            local_model = copy.deepcopy(global_model)
            local_model.load_state_dict(fed_model_weights)
            local_model.to(device)

            # Build mapping param -> name
            param_to_name = {id(param): name for name, param in local_model.named_parameters()}

            if use_sparse:
                client.decompress_mask()  # Decompress the client's mask
                optimizer = SparseSGD(local_model.parameters(),
                                      lr=LR,
                                      momentum=MOMENTUM,
                                      weight_decay=WEIGHT_DECAY,
                                      mask_dict=client.mask,
                                      param_to_name=param_to_name)
            else:
                optimizer = torch.optim.SGD(local_model.parameters(),
                                            lr=LR,
                                            momentum=MOMENTUM,
                                            weight_decay=WEIGHT_DECAY)

            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_MAX) if T_MAX else None

            # Train the local model on the client
            train_loss, train_acc = train_model_client(local_model, criterion, optimizer, scheduler, client, J, device=device)
            round_train_losses.append(train_loss)
            round_train_accs.append(train_acc)

            if verbose:
                print(f"Client {client.client_id} -> Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")

            # === Collect local weights for FedAvg ===
            local_sizes.append(client.num_samples())

            # 🔹 For reduced communication
            local_state = {k: v.cpu().detach() for k, v in local_model.state_dict().items()}
            if send_only_mask_updates and use_sparse:
                delta_state = {}     # delta_state will contain only active parameters, all the others will be 0.
                for k in local_state.keys():   # for each layer
                    delta = local_state[k] - fed_model_weights[k].cpu()
                    # Apply mask only if it exists for this parameter
                    if client.mask and k in client.mask:
                        mask = client.mask[k].to(delta.device)
                        active_indices = mask.nonzero(as_tuple=True)
                        delta_state[k] = {
                            'indices': active_indices,
                            'values': delta[active_indices],
                            'shape': delta.shape
                        }
                    else:
                        delta_state[k] = {
                            'indices': torch.tensor([], dtype=torch.long),
                            'values': torch.tensor([]),
                            'shape': delta.shape
                        }

                local_weights.append(delta_state)

                comm_this_client = 0
                for v in delta_state.values():
                    # values
                    comm_this_client += v['values'].numel()
                    #print('values', v['values'].numel())

                    # indices (supporta tuple di tensori per tensori multidimensionali)
                    if isinstance(v['indices'], tuple):
                        comm_this_client += sum(idx.numel() for idx in v['indices'])
                        #print('indices', sum(idx.numel() for idx in v['indices']))
                    else:
                        comm_this_client += v['indices'].numel()

                    # shape (piccolo overhead)
                    comm_this_client += torch.tensor(v['shape']).numel()
                #comm_this_client = sum(len(v['values']) for v in delta_state.values())    # Count only active values
            else:
                local_weights.append(local_state)
                comm_this_client = sum(v.numel() for v in local_state.values())

            # Count number of communicated parameters
            comm_this_round += comm_this_client

            # Free GPU memory
            del local_model, optimizer, scheduler
            torch.cuda.empty_cache()

        # Update total communicated parameters
        tot_comm += comm_this_round

        # === FedAvg aggregation ===
        # Floating tensors are averaged
        # Integer tensors are copied from the first client
        total_samples = sum(local_sizes)

        # 🔹 Reduced communication scenario
        if send_only_mask_updates and use_sparse:
            # Add delta updates to global weights
            for key in fed_model_weights.keys():     # compute the weighted average of the deltas using local_sizes[i] / total_samples.
                if fed_model_weights[key].dtype.is_floating_point:
                    total_update = torch.zeros_like(fed_model_weights[key])

                    # Recostruction of the sparse cleint weigths
                    for i in range(len(local_weights)):
                        sparse_dict = local_weights[i][key]    # delta sparse for layer key of client i.
                        tensor_i = torch.zeros(sparse_dict['shape'], device=total_update.device)     # Reconstruction

                        indices = sparse_dict['indices']
                        values = sparse_dict['values'].to(total_update.device)
                        if isinstance(indices, tuple) and len(indices) > 0 and indices[0].numel() > 0:   # Check if there are active parameters + Only assign if there are actually indices (otherwise remains 0)
                            tensor_i[indices] = values

                        total_update += tensor_i * (local_sizes[i] / total_samples)
                    fed_model_weights[key] = fed_model_weights[key].to(total_update.device) + total_update   # add  to the global weights
                else:
                    pass   # Integer tensors remain unchanged
        else:
            # Full communication: standard FedAvg
            for key in local_weights[0].keys():
                tensor0 = local_weights[0][key]
                if tensor0.dtype.is_floating_point:
                    fed_model_weights[key] = sum(local_weights[i][key] * (local_sizes[i]/total_samples)
                                                 for i in range(len(local_weights)))
                else:
                    fed_model_weights[key] = tensor0.clone()

        # Update the global model
        global_model.load_state_dict(fed_model_weights)
        global_model.to(device)      # <- NEW

        # Global evaluation
        avg_train_loss = np.mean(round_train_losses)
        avg_train_acc = np.mean(round_train_accs)
        val_test_loss, val_test_acc = evaluate_model(global_model, val_test_loader, criterion)

        if verbose or epoch == 0 or (epoch + 1) % 5 == 0:
            print(f"Round {epoch+1} -> Avg Train Loss: {avg_train_loss:.4f}, Avg Train Acc: {avg_train_acc:.4f}")
            print(f"Round {epoch+1} -> Val Loss: {val_test_loss:.4f}, Val Acc: {val_test_acc:.4f}")

        # 🔹Communication
        print(f"Round {epoch+1} -> Communicated Parameters: {comm_this_round:,}")


        val_test_loss_s.append(val_test_loss)
        val_test_acc_s.append(val_test_acc)
        avg_train_loss_s.append(avg_train_loss)
        avg_train_acc_s.append(avg_train_acc)

        # Save checkpoint
        if checkpoints and checkpoint_path:
            torch.save(global_model.state_dict(), f"{checkpoint_path}_round{epoch+1}.pth")

    # 🔹 Return total communicated parameters if requested
    if count:
        return global_model, val_test_loss_s, val_test_acc_s, avg_train_loss_s, avg_train_acc_s, tot_comm

    return global_model, val_test_loss_s, val_test_acc_s, avg_train_loss_s, avg_train_acc_s

# %% [markdown]
# # _________________________________________________________________________________________________________________________

# %% [markdown]
# # Communication

# %%
set_seeds(123)

FLAG = "iid"
Nc = None
J = 4
SPARSITY = 0.8   #0.5
C_ROUNDS = 1


N_EP = 10
K = 100
C = 0.1
LR = 5e-4
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-5
T_MAX = J * len(test_loader)
VERBOSE = True
KEEP = 'least'


SEND_ONLY_MASK_UPDATES_A = False # Run A: Dense
SEND_ONLY_MASK_UPDATES_B = True  # Run B: Sparse

# Model with pre-trained classifier
device_cpu = torch.device("cpu")
dino_vits16 = torch.hub.load('facebookresearch/dino:main', 'dino_vits16', force_reload=False)
dino_vits16 = dino_vits16.to(device_cpu)
global_model_cpu = DINOWithHead(backbone=dino_vits16, num_classes=100).to(device_cpu)
model_filename = f"global_model_FL_HEAD_{FLAG}_J{J}_Nc{Nc}.pth"

global_model_cpu.train()
for name, param in global_model_cpu.named_parameters():
    param.requires_grad = not name.startswith("head")
global_model_cpu.head.eval()

# 2 copies for 2 experiements
device_gpu = torch.device("cuda" if torch.cuda.is_available() else "cpu")
imported_model_train_1 = copy.deepcopy(global_model_cpu).to(device_gpu)
imported_model_train_2 = copy.deepcopy(global_model_cpu).to(device_gpu)


# --- IMPORTING CLIENTS ---
clients_filename = f"clients_FL_HEAD_{FLAG}_J{J}_Nc{Nc}.pkl"
with open(clients_filename, 'rb') as f:
    clients_1 = pickle.load(f)
with open(clients_filename, 'rb') as f:
    clients_2 = pickle.load(f)


criterion = nn.CrossEntropyLoss()
# Out:
# Using cache found in C:\Users\vidag/.cache\torch\hub\facebookresearch_dino_main

# %%
# Calibration
calibrate_all_clients(clients_1, imported_model_train_1, device_gpu, R=C_ROUNDS, final_sparsity=SPARSITY, lr=LR, keep=KEEP)
calibrate_all_clients(clients_2, imported_model_train_2, device_gpu, R=C_ROUNDS, final_sparsity=SPARSITY, lr=LR, keep=KEEP)
# Out:
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 1 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 2 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 3 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 4 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 5 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 6 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 7 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 8 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 9 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 10 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 11 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 12 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 13 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 14 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 15 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 16 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 17 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 18 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 19 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 20 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 21 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 22 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 23 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 24 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 25 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 26 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 27 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 28 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 29 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 30 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 31 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 32 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 33 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 34 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 35 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 36 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 37 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 38 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 39 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 40 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 41 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 42 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 43 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 44 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 45 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 46 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 47 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 48 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 49 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 50 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 51 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 52 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 53 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 54 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 55 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 56 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 57 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 58 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 59 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 60 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 61 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 62 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 63 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 64 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 65 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 66 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 67 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 68 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 69 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 70 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 71 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 72 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 73 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 74 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 75 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 76 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 77 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 78 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 79 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 80 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 81 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 82 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 83 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 84 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 85 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 86 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 87 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 88 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 89 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 90 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 91 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 92 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 93 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 94 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 95 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 96 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 97 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 98 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 99 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 100 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 1 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 2 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 3 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 4 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 5 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 6 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 7 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 8 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 9 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 10 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 11 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 12 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 13 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 14 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 15 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 16 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 17 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 18 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 19 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 20 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 21 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 22 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 23 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 24 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 25 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 26 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 27 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 28 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 29 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 30 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 31 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 32 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 33 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 34 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 35 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 36 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 37 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 38 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 39 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 40 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 41 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 42 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 43 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 44 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 45 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 46 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 47 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 48 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 49 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 50 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 51 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 52 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 53 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 54 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 55 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 56 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 57 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 58 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 59 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 60 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 61 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 62 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 63 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 64 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 65 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 66 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 67 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 68 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 69 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 70 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 71 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 72 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 73 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 74 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 75 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 76 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 77 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 78 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 79 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 80 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 81 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 82 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 83 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 84 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 85 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 86 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 87 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 88 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 89 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 90 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 91 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 92 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 93 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 94 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 95 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 96 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 97 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 98 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 99 -> mask calibrated (sparsity=0.5)
# [Round = 1] Sparsity = 0.5000
# Active parameters: 10832832/21665664 (50.00%)
# ✅ Client 100 -> mask calibrated (sparsity=0.5)

# %%
set_seeds(123)
################################################
# === RUN 1: DENSE COMMUNICATION (A) ===
################################################

start_time = time.time()
best_model_A, test_losses_A, test_accs_A, _, _, tot_comm_A = train_test_model_FL(
    global_model=imported_model_train_1,
    criterion=criterion,
    LR=LR, MOMENTUM=MOMENTUM, WEIGHT_DECAY=WEIGHT_DECAY, T_MAX=T_MAX,
    clients=clients_1,
    val_test_loader=test_loader,
    num_epochs=N_EP, C=C, J=J,
    verbose=VERBOSE,
    use_sparse=True,
    send_only_mask_updates=SEND_ONLY_MASK_UPDATES_A,
    count=True
)
end_time = time.time()
elapsed_time = end_time - start_time

results = {
    "run_A": {
        "send_only_mask_updates": SEND_ONLY_MASK_UPDATES_A,
        "tot_comm": tot_comm_A,
        "test_accuracies": test_accs_A,
        "test_losses": test_losses_A,
        "time_sec":elapsed_time
    }
}

json_filename = f"results_comm_A_{SPARSITY}.json"

with open(json_filename, "w") as f:
    json.dump(results, f, indent=2)
# Out:
# --- Federated Round 1/10 ---
# Client 9 -> Train Loss: 1.1957, Train Acc: 0.7640
# Client 71 -> Train Loss: 1.2329, Train Acc: 0.7760
# Client 83 -> Train Loss: 1.0772, Train Acc: 0.8020
# Client 29 -> Train Loss: 1.1288, Train Acc: 0.7940
# Client 64 -> Train Loss: 1.0739, Train Acc: 0.8100
# Client 1 -> Train Loss: 1.1563, Train Acc: 0.7920
# Client 6 -> Train Loss: 1.0515, Train Acc: 0.8280
# Client 51 -> Train Loss: 0.9640, Train Acc: 0.8280
# Client 82 -> Train Loss: 1.1642, Train Acc: 0.7960
# Client 5 -> Train Loss: 0.9767, Train Acc: 0.8460
# Round 1 -> Avg Train Loss: 1.1021, Avg Train Acc: 0.8036
# Round 1 -> Val Loss: 5.4770, Val Acc: 0.0444
# Round 1 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 2/10 ---
# Client 89 -> Train Loss: 0.4141, Train Acc: 0.9640
# Client 73 -> Train Loss: 0.3129, Train Acc: 0.9800
# Client 13 -> Train Loss: 0.7056, Train Acc: 0.9100
# Client 65 -> Train Loss: 0.3872, Train Acc: 0.9700
# Client 35 -> Train Loss: 0.5209, Train Acc: 0.9280
# Client 70 -> Train Loss: 0.5045, Train Acc: 0.9400
# Client 79 -> Train Loss: 0.6092, Train Acc: 0.9200
# Client 94 -> Train Loss: 0.7794, Train Acc: 0.8900
# Client 92 -> Train Loss: 0.5962, Train Acc: 0.9140
# Client 20 -> Train Loss: 0.4106, Train Acc: 0.9520
# Round 2 -> Avg Train Loss: 0.5240, Avg Train Acc: 0.9368
# Round 2 -> Val Loss: 4.1435, Val Acc: 0.1499
# Round 2 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 3/10 ---
# Client 12 -> Train Loss: 0.0839, Train Acc: 0.9980
# Client 70 -> Train Loss: 0.0324, Train Acc: 1.0000
# Client 4 -> Train Loss: 0.0648, Train Acc: 0.9980
# Client 90 -> Train Loss: 0.0582, Train Acc: 1.0000
# Client 91 -> Train Loss: 0.0622, Train Acc: 1.0000
# Client 93 -> Train Loss: 0.0558, Train Acc: 1.0000
# Client 100 -> Train Loss: 0.0556, Train Acc: 0.9980
# Client 21 -> Train Loss: 0.0488, Train Acc: 1.0000
# Client 56 -> Train Loss: 0.0595, Train Acc: 1.0000
# Client 61 -> Train Loss: 0.0699, Train Acc: 1.0000
# Round 3 -> Avg Train Loss: 0.0591, Avg Train Acc: 0.9994
# Round 3 -> Val Loss: 3.4403, Val Acc: 0.2422
# Round 3 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 4/10 ---
# Client 14 -> Train Loss: 0.0284, Train Acc: 0.9980
# Client 30 -> Train Loss: 0.0265, Train Acc: 1.0000
# Client 16 -> Train Loss: 0.0281, Train Acc: 1.0000
# Client 97 -> Train Loss: 0.0288, Train Acc: 1.0000
# Client 5 -> Train Loss: 0.0198, Train Acc: 1.0000
# Client 12 -> Train Loss: 0.0157, Train Acc: 1.0000
# Client 67 -> Train Loss: 0.0234, Train Acc: 1.0000
# Client 70 -> Train Loss: 0.0157, Train Acc: 1.0000
# Client 34 -> Train Loss: 0.0278, Train Acc: 1.0000
# Client 44 -> Train Loss: 0.0274, Train Acc: 1.0000
# Round 4 -> Avg Train Loss: 0.0242, Avg Train Acc: 0.9998
# Round 4 -> Val Loss: 2.9323, Val Acc: 0.3249
# Round 4 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 5/10 ---
# Client 23 -> Train Loss: 0.0215, Train Acc: 0.9980
# Client 22 -> Train Loss: 0.0213, Train Acc: 1.0000
# Client 74 -> Train Loss: 0.0228, Train Acc: 1.0000
# Client 12 -> Train Loss: 0.0133, Train Acc: 1.0000
# Client 70 -> Train Loss: 0.0155, Train Acc: 1.0000
# Client 43 -> Train Loss: 0.0194, Train Acc: 1.0000
# Client 58 -> Train Loss: 0.0220, Train Acc: 0.9980
# Client 41 -> Train Loss: 0.0257, Train Acc: 1.0000
# Client 6 -> Train Loss: 0.0185, Train Acc: 1.0000
# Client 85 -> Train Loss: 0.0194, Train Acc: 1.0000
# Round 5 -> Avg Train Loss: 0.0200, Avg Train Acc: 0.9996
# Round 5 -> Val Loss: 2.5422, Val Acc: 0.3911
# Round 5 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 6/10 ---
# Client 58 -> Train Loss: 0.0147, Train Acc: 1.0000
# Client 98 -> Train Loss: 0.0189, Train Acc: 1.0000
# Client 89 -> Train Loss: 0.0182, Train Acc: 1.0000
# Client 34 -> Train Loss: 0.0148, Train Acc: 1.0000
# Client 2 -> Train Loss: 0.0239, Train Acc: 1.0000
# Client 11 -> Train Loss: 0.0245, Train Acc: 0.9980
# Client 64 -> Train Loss: 0.0182, Train Acc: 1.0000
# Client 37 -> Train Loss: 0.0223, Train Acc: 1.0000
# Client 38 -> Train Loss: 0.0176, Train Acc: 1.0000
# Client 19 -> Train Loss: 0.0192, Train Acc: 1.0000
# Round 6 -> Avg Train Loss: 0.0192, Avg Train Acc: 0.9998
# Round 6 -> Val Loss: 2.2554, Val Acc: 0.4411
# Round 6 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 7/10 ---
# Client 42 -> Train Loss: 0.0189, Train Acc: 1.0000
# Client 61 -> Train Loss: 0.0160, Train Acc: 1.0000
# Client 96 -> Train Loss: 0.0173, Train Acc: 1.0000
# Client 1 -> Train Loss: 0.0162, Train Acc: 1.0000
# Client 99 -> Train Loss: 0.0159, Train Acc: 1.0000
# Client 93 -> Train Loss: 0.0146, Train Acc: 1.0000
# Client 10 -> Train Loss: 0.0238, Train Acc: 1.0000
# Client 43 -> Train Loss: 0.0155, Train Acc: 1.0000
# Client 63 -> Train Loss: 0.0187, Train Acc: 1.0000
# Client 91 -> Train Loss: 0.0167, Train Acc: 1.0000
# Round 7 -> Avg Train Loss: 0.0174, Avg Train Acc: 1.0000
# Round 7 -> Val Loss: 2.0394, Val Acc: 0.4808
# Round 7 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 8/10 ---
# Client 72 -> Train Loss: 0.0184, Train Acc: 1.0000
# Client 59 -> Train Loss: 0.0157, Train Acc: 1.0000
# Client 100 -> Train Loss: 0.0155, Train Acc: 1.0000
# Client 44 -> Train Loss: 0.0182, Train Acc: 0.9980
# Client 60 -> Train Loss: 0.0184, Train Acc: 1.0000
# Client 79 -> Train Loss: 0.0151, Train Acc: 1.0000
# Client 91 -> Train Loss: 0.0149, Train Acc: 1.0000
# Client 7 -> Train Loss: 0.0196, Train Acc: 1.0000
# Client 78 -> Train Loss: 0.0144, Train Acc: 1.0000
# Client 73 -> Train Loss: 0.0151, Train Acc: 1.0000
# Round 8 -> Avg Train Loss: 0.0165, Avg Train Acc: 0.9998
# Round 8 -> Val Loss: 1.8857, Val Acc: 0.5170
# Round 8 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 9/10 ---
# Client 74 -> Train Loss: 0.0131, Train Acc: 1.0000
# Client 11 -> Train Loss: 0.0136, Train Acc: 1.0000
# Client 30 -> Train Loss: 0.0142, Train Acc: 1.0000
# Client 75 -> Train Loss: 0.0149, Train Acc: 1.0000
# Client 23 -> Train Loss: 0.0157, Train Acc: 1.0000
# Client 66 -> Train Loss: 0.0146, Train Acc: 1.0000
# Client 48 -> Train Loss: 0.0183, Train Acc: 1.0000
# Client 52 -> Train Loss: 0.0173, Train Acc: 1.0000
# Client 100 -> Train Loss: 0.0127, Train Acc: 1.0000
# Client 10 -> Train Loss: 0.0143, Train Acc: 1.0000
# Round 9 -> Avg Train Loss: 0.0149, Avg Train Acc: 1.0000
# Round 9 -> Val Loss: 1.7781, Val Acc: 0.5423
# Round 9 -> Communicated Parameters: 217,041,640
#
# --- Federated Round 10/10 ---
# Client 27 -> Train Loss: 0.0154, Train Acc: 1.0000
# Client 93 -> Train Loss: 0.0107, Train Acc: 1.0000
# Client 13 -> Train Loss: 0.0167, Train Acc: 1.0000
# Client 59 -> Train Loss: 0.0147, Train Acc: 1.0000
# Client 84 -> Train Loss: 0.0211, Train Acc: 0.9980
# Client 14 -> Train Loss: 0.0148, Train Acc: 1.0000
# Client 42 -> Train Loss: 0.0145, Train Acc: 1.0000
# Client 34 -> Train Loss: 0.0115, Train Acc: 1.0000
# Client 11 -> Train Loss: 0.0103, Train Acc: 1.0000
# Client 22 -> Train Loss: 0.0142, Train Acc: 1.0000
# Round 10 -> Avg Train Loss: 0.0144, Avg Train Acc: 0.9998
# Round 10 -> Val Loss: 1.7070, Val Acc: 0.5607
# Round 10 -> Communicated Parameters: 217,041,640

# %%
set_seeds(123)
################################################
# === RUN 2: SPARSE COMMUNICATION (B) ===
################################################
print("\n" + "="*50)
print("AVVIO RUN B: Comunicazione Sparsa")
print("="*50)
start_time = time.time()
best_model_B, test_losses_B, test_accs_B, avg_train_losses_B, avg_train_accs_B, tot_comm_B = train_test_model_FL(
    global_model=imported_model_train_2,
    criterion=criterion,
    LR=LR, MOMENTUM=MOMENTUM, WEIGHT_DECAY=WEIGHT_DECAY, T_MAX=T_MAX,
    clients=clients_2,
    val_test_loader=test_loader,
    num_epochs=N_EP, C=C, J=J,
    verbose=VERBOSE,
    use_sparse=True,
    send_only_mask_updates=SEND_ONLY_MASK_UPDATES_B,
    count=True
)
end_time = time.time()
elapsed_time = end_time - start_time
results["run_B"] = {
    "send_only_mask_updates": SEND_ONLY_MASK_UPDATES_B,
    "tot_comm": tot_comm_B,
    "test_accuracies": test_accs_B,
    "test_losses": test_losses_A,
    "time_sec":elapsed_time
    }

with open(f"fl_sparse_comparison_COMMUNICATION_{SPARSITY}.json", "w") as f:
    json.dump(results, f, indent=4)
# Out:
# ==================================================
# AVVIO RUN B: Comunicazione Sparsa
# ==================================================
#
# --- Federated Round 1/10 ---
# Client 9 -> Train Loss: 1.1681, Train Acc: 0.7780
# Client 71 -> Train Loss: 1.2399, Train Acc: 0.7740
# Client 83 -> Train Loss: 1.0890, Train Acc: 0.8000
# Client 29 -> Train Loss: 1.0907, Train Acc: 0.8080
# Client 64 -> Train Loss: 1.0785, Train Acc: 0.8040
# Client 1 -> Train Loss: 1.1458, Train Acc: 0.7920
# Client 6 -> Train Loss: 1.0397, Train Acc: 0.8220
# Client 51 -> Train Loss: 0.9446, Train Acc: 0.8320
# Client 82 -> Train Loss: 1.2285, Train Acc: 0.7760
# Client 5 -> Train Loss: 1.0058, Train Acc: 0.8360
# Round 1 -> Avg Train Loss: 1.1031, Avg Train Acc: 0.8022
# Round 1 -> Val Loss: 5.4682, Val Acc: 0.0440
# Round 1 -> Communicated Parameters: 325,071,074
#
# --- Federated Round 2/10 ---
# Client 89 -> Train Loss: 0.4472, Train Acc: 0.9540
# Client 73 -> Train Loss: 0.2704, Train Acc: 0.9840
# Client 13 -> Train Loss: 0.5831, Train Acc: 0.9420
# Client 65 -> Train Loss: 0.4078, Train Acc: 0.9640
# Client 35 -> Train Loss: 0.4992, Train Acc: 0.9360
# Client 70 -> Train Loss: 0.4845, Train Acc: 0.9440
# Client 79 -> Train Loss: 0.5836, Train Acc: 0.9180
# Client 94 -> Train Loss: 0.6501, Train Acc: 0.9140
# Client 92 -> Train Loss: 0.6445, Train Acc: 0.9140
# Client 20 -> Train Loss: 0.4137, Train Acc: 0.9480
# Round 2 -> Avg Train Loss: 0.4984, Avg Train Acc: 0.9418
# Round 2 -> Val Loss: 4.1449, Val Acc: 0.1509
# Round 2 -> Communicated Parameters: 325,071,350
#
# --- Federated Round 3/10 ---
# Client 12 -> Train Loss: 0.0806, Train Acc: 0.9980
# Client 70 -> Train Loss: 0.0318, Train Acc: 1.0000
# Client 4 -> Train Loss: 0.0595, Train Acc: 0.9980
# Client 90 -> Train Loss: 0.0556, Train Acc: 1.0000
# Client 91 -> Train Loss: 0.0716, Train Acc: 1.0000
# Client 93 -> Train Loss: 0.0569, Train Acc: 1.0000
# Client 100 -> Train Loss: 0.0546, Train Acc: 0.9980
# Client 21 -> Train Loss: 0.0492, Train Acc: 1.0000
# Client 56 -> Train Loss: 0.0610, Train Acc: 0.9980
# Client 61 -> Train Loss: 0.0683, Train Acc: 1.0000
# Round 3 -> Avg Train Loss: 0.0589, Avg Train Acc: 0.9992
# Round 3 -> Val Loss: 3.4483, Val Acc: 0.2419
# Round 3 -> Communicated Parameters: 325,071,091
#
# --- Federated Round 4/10 ---
# Client 14 -> Train Loss: 0.0269, Train Acc: 0.9980
# Client 30 -> Train Loss: 0.0285, Train Acc: 1.0000
# Client 16 -> Train Loss: 0.0280, Train Acc: 1.0000
# Client 97 -> Train Loss: 0.0276, Train Acc: 1.0000
# Client 5 -> Train Loss: 0.0205, Train Acc: 1.0000
# Client 12 -> Train Loss: 0.0146, Train Acc: 1.0000
# Client 67 -> Train Loss: 0.0229, Train Acc: 1.0000
# Client 70 -> Train Loss: 0.0161, Train Acc: 1.0000
# Client 34 -> Train Loss: 0.0309, Train Acc: 1.0000
# Client 44 -> Train Loss: 0.0272, Train Acc: 1.0000
# Round 4 -> Avg Train Loss: 0.0243, Avg Train Acc: 0.9998
# Round 4 -> Val Loss: 2.9344, Val Acc: 0.3266
# Round 4 -> Communicated Parameters: 325,071,641
#
# --- Federated Round 5/10 ---
# Client 23 -> Train Loss: 0.0229, Train Acc: 0.9980
# Client 22 -> Train Loss: 0.0222, Train Acc: 1.0000
# Client 74 -> Train Loss: 0.0219, Train Acc: 1.0000
# Client 12 -> Train Loss: 0.0140, Train Acc: 1.0000
# Client 70 -> Train Loss: 0.0143, Train Acc: 1.0000
# Client 43 -> Train Loss: 0.0186, Train Acc: 1.0000
# Client 58 -> Train Loss: 0.0221, Train Acc: 1.0000
# Client 41 -> Train Loss: 0.0271, Train Acc: 0.9980
# Client 6 -> Train Loss: 0.0182, Train Acc: 1.0000
# Client 85 -> Train Loss: 0.0192, Train Acc: 1.0000
# Round 5 -> Avg Train Loss: 0.0200, Avg Train Acc: 0.9996
# Round 5 -> Val Loss: 2.5437, Val Acc: 0.3907
# Round 5 -> Communicated Parameters: 325,070,576
#
# --- Federated Round 6/10 ---
# Client 58 -> Train Loss: 0.0148, Train Acc: 1.0000
# Client 98 -> Train Loss: 0.0200, Train Acc: 1.0000
# Client 89 -> Train Loss: 0.0181, Train Acc: 1.0000
# Client 34 -> Train Loss: 0.0150, Train Acc: 1.0000
# Client 2 -> Train Loss: 0.0271, Train Acc: 1.0000
# Client 11 -> Train Loss: 0.0254, Train Acc: 1.0000
# Client 64 -> Train Loss: 0.0177, Train Acc: 1.0000
# Client 37 -> Train Loss: 0.0232, Train Acc: 1.0000
# Client 38 -> Train Loss: 0.0173, Train Acc: 1.0000
# Client 19 -> Train Loss: 0.0204, Train Acc: 1.0000
# Round 6 -> Avg Train Loss: 0.0199, Avg Train Acc: 1.0000
# Round 6 -> Val Loss: 2.2583, Val Acc: 0.4410
# Round 6 -> Communicated Parameters: 325,071,440
#
# --- Federated Round 7/10 ---
# Client 42 -> Train Loss: 0.0210, Train Acc: 1.0000
# Client 61 -> Train Loss: 0.0170, Train Acc: 1.0000
# Client 96 -> Train Loss: 0.0179, Train Acc: 1.0000
# Client 1 -> Train Loss: 0.0160, Train Acc: 1.0000
# Client 99 -> Train Loss: 0.0157, Train Acc: 1.0000
# Client 93 -> Train Loss: 0.0151, Train Acc: 1.0000
# Client 10 -> Train Loss: 0.0227, Train Acc: 1.0000
# Client 43 -> Train Loss: 0.0148, Train Acc: 1.0000
# Client 63 -> Train Loss: 0.0199, Train Acc: 1.0000
# Client 91 -> Train Loss: 0.0175, Train Acc: 1.0000
# Round 7 -> Avg Train Loss: 0.0178, Avg Train Acc: 1.0000
# Round 7 -> Val Loss: 2.0368, Val Acc: 0.4812
# Round 7 -> Communicated Parameters: 325,071,374
#
# --- Federated Round 8/10 ---
# Client 72 -> Train Loss: 0.0178, Train Acc: 1.0000
# Client 59 -> Train Loss: 0.0153, Train Acc: 1.0000
# Client 100 -> Train Loss: 0.0154, Train Acc: 1.0000
# Client 44 -> Train Loss: 0.0161, Train Acc: 0.9980
# Client 60 -> Train Loss: 0.0190, Train Acc: 1.0000
# Client 79 -> Train Loss: 0.0151, Train Acc: 1.0000
# Client 91 -> Train Loss: 0.0143, Train Acc: 1.0000
# Client 7 -> Train Loss: 0.0192, Train Acc: 1.0000
# Client 78 -> Train Loss: 0.0143, Train Acc: 1.0000
# Client 73 -> Train Loss: 0.0147, Train Acc: 1.0000
# Round 8 -> Avg Train Loss: 0.0161, Avg Train Acc: 0.9998
# Round 8 -> Val Loss: 1.8845, Val Acc: 0.5133
# Round 8 -> Communicated Parameters: 325,070,886
#
# --- Federated Round 9/10 ---
# Client 74 -> Train Loss: 0.0130, Train Acc: 1.0000
# Client 11 -> Train Loss: 0.0132, Train Acc: 1.0000
# Client 30 -> Train Loss: 0.0145, Train Acc: 1.0000
# Client 75 -> Train Loss: 0.0146, Train Acc: 1.0000
# Client 23 -> Train Loss: 0.0145, Train Acc: 1.0000
# Client 66 -> Train Loss: 0.0143, Train Acc: 1.0000
# Client 48 -> Train Loss: 0.0201, Train Acc: 1.0000
# Client 52 -> Train Loss: 0.0175, Train Acc: 1.0000
# Client 100 -> Train Loss: 0.0122, Train Acc: 1.0000
# Client 10 -> Train Loss: 0.0145, Train Acc: 1.0000
# Round 9 -> Avg Train Loss: 0.0148, Avg Train Acc: 1.0000
# Round 9 -> Val Loss: 1.7749, Val Acc: 0.5433
# Round 9 -> Communicated Parameters: 325,071,528
#
# --- Federated Round 10/10 ---
# Client 27 -> Train Loss: 0.0155, Train Acc: 1.0000
# Client 93 -> Train Loss: 0.0108, Train Acc: 1.0000
# Client 13 -> Train Loss: 0.0173, Train Acc: 1.0000
# Client 59 -> Train Loss: 0.0141, Train Acc: 1.0000
# Client 84 -> Train Loss: 0.0196, Train Acc: 1.0000
# Client 14 -> Train Loss: 0.0148, Train Acc: 1.0000
# Client 42 -> Train Loss: 0.0146, Train Acc: 1.0000
# Client 34 -> Train Loss: 0.0117, Train Acc: 1.0000
# Client 11 -> Train Loss: 0.0104, Train Acc: 1.0000
# Client 22 -> Train Loss: 0.0151, Train Acc: 1.0000
# Round 10 -> Avg Train Loss: 0.0144, Avg Train Acc: 1.0000
# Round 10 -> Val Loss: 1.7044, Val Acc: 0.5617
# Round 10 -> Communicated Parameters: 325,071,327

# %%
with open("fl_sparse_comparison_COMMUNICATION_0.5.json", "r") as f:
    data_50 = json.load(f)

with open("fl_sparse_comparison_COMMUNICATION_0.8.json", "r") as f:
    data_80 = json.load(f)


runs = {
    "Original": data_50["run_A"],
#    "Sparse 50%": data_50["run_B"],
#    "Dense 80%": data_80["run_A"],
    "Reduced": data_80["run_B"]
}

# --- Communication summary ---
tot_comm = {k: v["tot_comm"] for k,v in runs.items()}

print("\n" + "="*50)
print("      Communication Results Summary")
print("="*50)
for k in tot_comm:
    print(f"{k}: {tot_comm[k]:,} parameters")
print("-"*50)


runs = {
    "Dense 50%": data_50["run_A"],
    "Sparse 50%": data_50["run_B"],
    "Dense 80%": data_80["run_A"],
    "Sparse 80%": data_80["run_B"]
}

# --- Plot comparison of communicated parameters ---
plt.figure(figsize=(10, 6))
bars = plt.bar(tot_comm.keys(), tot_comm.values(), color=['salmon', 'dodgerblue'])
plt.ylabel("Tot. Num. of Communicated Param.")
plt.title("Communication Comparison (80% sparsity)")
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{int(yval):,}',
             va='bottom', ha='center')
plt.show()

# --- Plot Test Accuracy per Epoch ---
plt.figure(figsize=(10, 6))
colors = ['dodgerblue','salmon','deepskyblue','lightcoral']
for idx, (label, run) in enumerate(runs.items()):
    plt.plot(range(1, len(run['test_accuracies'])+1), run['test_accuracies'],
             'o-', label=label, color=colors[idx])

plt.title('Test Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.tight_layout()
plt.show()
# Out:
# ==================================================
#       Communication Results Summary
# ==================================================
# Original: 2,170,416,400 parameters
# Reduced: 1,300,393,658 parameters
# --------------------------------------------------
